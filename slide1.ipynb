# %%
#Import needed library
import numpy as np
from __future__ import print_function
import prettyplotlib as ppl
import matplotlib.pyplot as plt
import pandas as pd
from pandas import Series, DataFrame

# %%
#Read csv File into dataFrame
#dfSlide1 = pd.read_csv('https://raw.githubusercontent.com/Sree-vathsan/CSE591-Data-Science-Project/master/baselineModel/slide1.csv')
dfSlide1 = pd.read_csv('https://raw.githubusercontent.com/Sree-vathsan/CSE595_DataAnalyticsSoftwareStack/master/slide1.csv')

# %%
fig, axes = plt.subplots(1, 1, figsize=(12,4))
area = 2
x = dfSlide1['X']
y = dfSlide1['Y']
N=len(y)
colors = np.random.rand(N)
ppl.scatter(axes,x,y,s=area, c=colors, alpha=0.5)

# %%
import matplotlib.patches as patches 
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection
from shapely.geometry import Polygon

fig1 = plt.figure(figsize=(20, 20)) 
ax1 = fig1.add_subplot(111) 
#fig1, axes1 = plt.subplots(1, 1, figsize=(12,4))
#print(dfSlide1[1:3])
#dfSlide2 = dfSlide1[1:3000]
#boundaries = dfSlide2['Boundaries']
boundaries = dfSlide1['Boundaries']
patchesArr = []
poly_area = []
poly_per = []
for bnd in boundaries:
    obj1 = bnd.split(';')
    #print(len(x1))
    xArr = []
    yArr = []
    points = []
    for pts in obj1:
        #print(len(pts))
        if(len(pts) > 0):
            obj2 = pts.split(',')
            points.append((float(obj2[0]),float(obj2[1])))
            xArr.append(obj2[0])
            yArr.append(obj2[1])
    #print(points)
    polygon = Polygon(points)
    poly_area.append(polygon.area)
    poly_per.append(polygon.length)
    #print(points)
    poly = patches.Polygon(points,alpha='0.2',ec='green',hatch='x',linestyle='dashed',fill=False) 
    #ax1.add_patch(poly)
    patchesArr.append(poly)
colors = 100*np.random.rand(len(patchesArr))
p = PatchCollection(patchesArr, cmap=matplotlib.cm.jet, alpha=0.4)
p.set_array(np.array(colors))
ax1.add_collection(p)
ax1.set_xlim(0,700) 
ax1.set_ylim(0,1500)
plt.show()
dfSlide1['Computed_Area'] = poly_area
dfSlide1['Computed Perimeter'] = poly_per
dfSlide1
# Out:
#            X       Y                                         Boundaries  Area  \
# 0        6.0     2.8  1.0,1.0;12.0,1.0;12.0,2.0;11.0,2.0;11.0,3.0;10...    54
# 1        3.3    16.2  1.0,12.0;4.0,12.0;4.0,13.0;5.0,13.0;5.0,14.0;6...    51
# 2        8.5   106.3  1.0,101.0;3.0,101.0;3.0,100.0;8.0,100.0;8.0,10...   168
# 3        8.8   240.7  1.0,240.0;3.0,240.0;3.0,239.0;4.0,239.0;4.0,23...   133
# 4        4.0   273.9  1.0,272.0;3.0,272.0;3.0,271.0;4.0,271.0;4.0,27...    64
# 5        5.2   453.8  1.0,451.0;3.0,451.0;3.0,450.0;4.0,450.0;4.0,44...   110
# 6        2.4   506.4  1.0,503.0;2.0,503.0;2.0,504.0;3.0,504.0;3.0,50...    27
# 7        5.5   557.6  1.0,553.0;6.0,553.0;6.0,554.0;8.0,554.0;8.0,55...    90
# 8        4.0   578.7  1.0,575.0;3.0,575.0;3.0,574.0;7.0,574.0;7.0,57...    72
# 9        5.3   615.3  1.0,612.0;4.0,612.0;4.0,613.0;8.0,613.0;8.0,61...    63
# 10       4.2   791.9  1.0,784.0;4.0,784.0;4.0,785.0;5.0,785.0;5.0,78...   109
