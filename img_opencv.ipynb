# %%
print("Hello OpenCV\n")
# Out:
# Hello OpenCV

# %%
#Import needed library
import numpy as np
import cv2
from matplotlib import pyplot as plt
from __future__ import print_function
import matplotlib.pyplot as plt
import pandas as pd
from pandas import Series, DataFrame

# %%
# Load an color image in grayscale
img = cv2.imread('path-image-100.000000.000000.jpg',cv2.IMREAD_COLOR)
plt.imshow(img, interpolation = 'bicubic')
dfSlide1 = pd.read_csv('https://raw.githubusercontent.com/Sree-vathsan/CSE595_DataAnalyticsSoftwareStack/master/slide1.csv')
N=len(dfSlide1['X'])
colors = np.random.rand(N)
boundaries = dfSlide1['Boundaries']

for bnd in boundaries:
    obj1 = bnd.split(';')
    xArr = []
    yArr = []
    points = []
    for pts in obj1:
        if(len(pts) > 0):
            obj2 = pts.split(',')
            points.append((float(obj2[0]),float(obj2[1])))
    #points = np.array(points,np.float)
    #print(points)
    #cv2.polylines(img, [points], isClosed=True, color=(255,0,0), thickness=3)
#cv2.line(img,(0,0),(511,511),(255,0,0),5)

r=100
points = [ [1.5*r,1.34*r], [r,2*r], [1.5*r,2.866*r], [2.5*r,2.866*r],[3*r,2*r],[2.5*r,1.34*r] ]
points = np.array(points,np.int0)
cv2.polylines(img,[points],True,(0,0,0),3)
plt.show()
#plt.imshow('image',img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
mypt = [(1.0, 1.0), (12.0, 1.0), (12.0, 2.0), (11.0, 2.0), (11.0, 3.0), (10.0, 3.0), (10.0, 4.0), (8.0, 4.0), (8.0, 5.0), (1.0, 5.0), (1.0, 1.0)]
mypt = np.array(mypt,np.float)
cv2.polylines(img,mypt,True,255,3)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-6c538aec5979> in <module>()
#       1 mypt = [(1.0, 1.0), (12.0, 1.0), (12.0, 2.0), (11.0, 2.0), (11.0, 3.0), (10.0, 3.0), (10.0, 4.0), (8.0, 4.0), (8.0, 5.0), (1.0, 5.0), (1.0, 1.0)]
#       2 mypt = np.array(mypt,np.float)
# ----> 3 cv2.polylines(img,mypt,True,255,3)
#
# error: C:\pisi\tmp\opencv-2.4.9-1\work\opencv-2.4.9\modules\core\src\drawing.cpp:2067: error: (-215) p.checkVector(2, CV_32S) >= 0 in function cv::polylines

# %%
r=100
img = cv2.imread('path-image-100.000000.000000.jpg',cv2.IMREAD_COLOR)
points = [ [1.5*r,1.34*r], [r,2*r], [1.5*r,2.866*r], [2.5*r,2.866*r],[3*r,2*r],[2.5*r,1.34*r] ]
points = np.array(points,np.int0)
cv2.polylines(img,[points],True,255,3)
plt.show()
